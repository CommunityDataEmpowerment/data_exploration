# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import numpy as np
from sodapy import Socrata
from app_token import app_token
from pgconnect import pgconnect

# %%
import json

# %%
import psycopg2

# %%
from sqlalchemy import create_engine

# %%
# sqlalchemy engine for using .to_sql
url = f"postgres+psycopg2://{user}:@{host}:5432/{db}"
engine = create_engine(url)

# %% [markdown]
# ### POSTGRES CONNECTION

# %%
db = pgconnect['db']
host = pgconnect['host']
user = pgconnect['user']

# %%
con = psycopg2.connect(database=db,host=host,user=user)

# %%
cur = con.cursor()

# %%
### write the uof_filenum table
cur.execute(open('create_uof_filenum.sql').read())
con.commit() # commit the create statement to the database

# %%
# columns for uof_filenum table
table_cols = ['objectid',
'zip',
'filenum',
'occurred_d',
'occurred_t',
'current_ba',
'offsex',
'offrace',
'hire_dt',
'off_injure',
'offcondtyp',
'off_hospit',
'service_ty',
'uof_reason',
'cycles_num',
'street_n',
'street',
'street_g',
'street_t',
'address',
'citnum',
'citrace',
'citsex',
'cit_injure',
'citcondtyp',
'cit_arrest',
'cit_infl_a',
'citcharget',
'council_district',
'ra',
'beat',
'sector',
'division',
'x',
'y',
'geocoded_column',
'year_reported']

# %% [markdown]
# ### API

# %%
limit = 6000

# %%
client = Socrata("www.dallasopendata.com", app_token=app_token['token'])

# %%
url_dict = dict (
    data_2019 ='46zb-7qgj',
    data_2018 ='33un-ry4j',
    data_2017 ='tsu5-ca6k',
    data_2016 ='99fn-pvaf',
    data_2015 ='594v-2cnd',
    data_2014 ='xiv3-e8g7',
    data_2013 ='6gnu-avpf'
    )

# %%
df_2019 = pd.DataFrame(client.get('46zb-7qgj', limit=limit))

# %%
df_2019.head()
# Out:
#   objectid    zip      filenum        uofnum               occurred_d  \
# 0     2817  75253  UF2019-1702  62295, 63542  2019-12-01T00:00:00.000
# 1     2234  75208  UF2019-1344         61093  2019-10-06T00:00:00.000
# 2     2755  75231  UF2019-1665         62820  2019-12-31T00:00:00.000
# 3     2110  75228  UF2019-1314         60990  2019-09-30T00:00:00.000
# 4     1663  75051  UF2019-1030  59592, 59600  2019-08-04T00:00:00.000
#
#   occurred_t current_ba offsex   offrace                  hire_dt  ...    ra  \
# 0   10:34 PM      11285   Male     White  2017-03-08T00:00:00.000  ...  6062
# 1   12:50 AM      11208   Male     White  2016-08-24T00:00:00.000  ...  4160
# 2   11:37 PM       9415   Male     White  2008-04-02T00:00:00.000  ...  6034
# 3    6:20 PM       9884   Male  Hispanic  2009-06-10T00:00:00.000  ...  1132
# 4   12:10 AM      10480   Male  Hispanic  2012-09-26T00:00:00.000  ...  None
#
#    beat sector   division            x            y  \
# 0   357    350  SOUTHEAST  2557123.437  6944231.397
# 1   444    440  SOUTHWEST  2474936.793  6952151.398
# 2   247    240  NORTHEAST  2508349.267  7001784.466
# 3   228    220  NORTHEAST  2536678.324  6999039.025
# 4  None   None       None  2433285.622   6953645.72
#
#                                      geocoded_column  \
# 0  {"type": "Point", "coordinates": [-96.586265, ...
# 1  {"type": "Point", "coordinates": [-96.853036, ...
# 2  {"type": "Point", "coordinates": [-96.741661, ...
# 3  {"type": "Point", "coordinates": [-96.649175, ...
# 4  {"type": "Point", "coordinates": [-96.98722, 3...
#
#   :@computed_region_sjyw_rtbm :@computed_region_2f7u_b5gs year_reported
# 0                           8                           3          2019
# 1                           1                           3          2019
# 2                          13                           3          2019
# 3                          13                           3          2019
# 4                        None                        None          2019
#
# [5 rows x 42 columns]

# %%
# adding the year reported values
df_2019['year_reported'] = '2019'

# %%
# convert the geocode column from dict to JSON string for load into database
df_2019['geocoded_column'] = df_2019['geocoded_column'].apply(lambda x:json.dumps(x))

# %%
# replace NULL string values with None type for proper load into database
df_2019.replace(to_replace='NULL',inplace=True)
# Out:
# objectid                       None
# zip                            None
# filenum                        None
# uofnum                         None
# occurred_d                     None
# occurred_t                     None
# current_ba                     None
# offsex                         None
# offrace                        None
# hire_dt                        None
# off_injure                     None
# offcondtyp                     None
# off_hospit                     None
# service_ty                     None
# forcetype                      None
# uof_reason                     None
# cycles_num                     None
# forceeffec                     None
# street_n                       None
# street                         None
# street_g                       None
# street_t                       None
# address                        None
# citnum                         None
# citrace                        None
# citsex                         None
# cit_injure                     None
# citcondtyp                     None
# cit_arrest                     None
# cit_infl_a                     None
# citcharget                     None
# council_district               None
# ra                             None
# beat                           None
# sector                         None
# division                       None
# x                              None
# y                              None
# geocoded_column                None
# :@computed_region_sjyw_rtbm    None
# :@computed_region_2f7u_b5gs    None
# year_reported                  None
# dtype: object

# %%
# replace NaN string values with None type for proper load into database
df_2019.replace(to_replace='NaN',inplace=True)
# Out:
# objectid                       None
# zip                            None
# filenum                        None
# uofnum                         None
# occurred_d                     None
# occurred_t                     None
# current_ba                     None
# offsex                         None
# offrace                        None
# hire_dt                        None
# off_injure                     None
# offcondtyp                     None
# off_hospit                     None
# service_ty                     None
# forcetype                      None
# uof_reason                     None
# cycles_num                     None
# forceeffec                     None
# street_n                       None
# street                         None
# street_g                       None
# street_t                       None
# address                        None
# citnum                         None
# citrace                        None
# citsex                         None
# cit_injure                     None
# citcondtyp                     None
# cit_arrest                     None
# cit_infl_a                     None
# citcharget                     None
# council_district               None
# ra                             None
# beat                           None
# sector                         None
# division                       None
# x                              None
# y                              None
# geocoded_column                None
# :@computed_region_sjyw_rtbm    None
# :@computed_region_2f7u_b5gs    None
# year_reported                  None
# dtype: object

# %%
# cast all empty values into None type
df_2019.where(pd.notnull(df_2019),None,inplace=True)

# %%
# load into table
df_2019[table_cols].to_sql('uof_filenum',engine,schema='cdep',if_exists='append',index=False,method='multi')

# %% [markdown]
# ## Load 2018 data

# %%
df_2018 = pd.DataFrame(client.get(url_dict['data_2018'], limit=limit))

# %%
df_2018.columns
# Out:
# Index(['filenum', 'uofnum', 'occurred_d', 'current_ba', 'offsex', 'offrace',
#        'hire_dt', 'off_injure', 'offcondtyp', 'off_hospit', 'service_ty',
#        'forcetype', 'uof_reason', 'cycles_num', 'forceeffec', 'street_n',
#        'street', 'street_g', 'street_t', 'address', 'citnum', 'citrace',
#        'citsex', 'cit_injure', 'citcondtyp', 'cit_arrest', 'cit_infl_a',
#        'citcharget', 'ra', 'beat', 'sector', 'division', 'geocoded_column',
#        ':@computed_region_sjyw_rtbm', ':@computed_region_2f7u_b5gs'],
#       dtype='object')

# %%
# adding the year reported values
df_2018['year_reported'] = '2018'

# %%
# convert the geocode column from dict to JSON string for load into database
df_2018['geocoded_column'] = df_2018['geocoded_column'].apply(lambda x:json.dumps(x))

# %%
# replace NULL string values with None type for proper load into database
df_2018.replace(to_replace='NULL',inplace=True)
# Out:
# filenum                        None
# uofnum                         None
# occurred_d                     None
# current_ba                     None
# offsex                         None
# offrace                        None
# hire_dt                        None
# off_injure                     None
# offcondtyp                     None
# off_hospit                     None
# service_ty                     None
# forcetype                      None
# uof_reason                     None
# cycles_num                     None
# forceeffec                     None
# street_n                       None
# street                         None
# street_g                       None
# street_t                       None
# address                        None
# citnum                         None
# citrace                        None
# citsex                         None
# cit_injure                     None
# citcondtyp                     None
# cit_arrest                     None
# cit_infl_a                     None
# citcharget                     None
# ra                             None
# beat                           None
# sector                         None
# division                       None
# geocoded_column                None
# :@computed_region_sjyw_rtbm    None
# :@computed_region_2f7u_b5gs    None
# year_reported                  None
# dtype: object

# %%
# replace NaN string values with None type for proper load into database
df_2018.replace(to_replace='NaN',inplace=True)
# Out:
# filenum                        None
# uofnum                         None
# occurred_d                     None
# current_ba                     None
# offsex                         None
# offrace                        None
# hire_dt                        None
# off_injure                     None
# offcondtyp                     None
# off_hospit                     None
# service_ty                     None
# forcetype                      None
# uof_reason                     None
# cycles_num                     None
# forceeffec                     None
# street_n                       None
# street                         None
# street_g                       None
# street_t                       None
# address                        None
# citnum                         None
# citrace                        None
# citsex                         None
# cit_injure                     None
# citcondtyp                     None
# cit_arrest                     None
# cit_infl_a                     None
# citcharget                     None
# ra                             None
# beat                           None
# sector                         None
# division                       None
# geocoded_column                None
# :@computed_region_sjyw_rtbm    None
# :@computed_region_2f7u_b5gs    None
# year_reported                  None
# dtype: object

# %%
# cast all empty values into None type
df_2018.where(pd.notnull(df_2018),None,inplace=True)

# %%
# load into table
df_2018[[item for item in table_cols if item in df_2018.columns]].to_sql('uof_filenum',engine,schema='cdep',if_exists='append',index=True,index_label='objectid',method='multi')

# %% [markdown]
# - - -

# %% [markdown]
# ## Experimental code for 2019 above

# %%
con.rollback() # for rolling back a failed transaction

# %%
df_2019[df_2019['geocoded_column']=='NaN']
# Out:
# Empty DataFrame
# Columns: [objectid, zip, filenum, uofnum, occurred_d, occurred_t, current_ba, offsex, offrace, hire_dt, off_injure, offcondtyp, off_hospit, service_ty, forcetype, uof_reason, cycles_num, forceeffec, street_n, street, street_g, street_t, address, citnum, citrace, citsex, cit_injure, citcondtyp, cit_arrest, cit_infl_a, citcharget, council_district, ra, beat, sector, division, x, y, geocoded_column, :@computed_region_sjyw_rtbm, :@computed_region_2f7u_b5gs, year_reported]
# Index: []
#
# [0 rows x 42 columns]

# %%
json.dumps(df_2019['geocoded_column'][0])
# Out:
# '{"type": "Point", "coordinates": [-96.586265, 32.702825]}'

# %%
df_2019[['off_injure',
       'offcondtyp', 'off_hospit', 'service_ty', 'forcetype', 'uof_reason',
       'cycles_num', 'forceeffec', 'street_n', 'street', 'street_g',
       'street_t', 'address', 'citnum', 'citrace', 'citsex', 'cit_injure']]
# Out:
#      off_injure                    offcondtyp off_hospit           service_ty  \
# 0         false  No injuries noted or visible      false         Service Call
# 1          true  No injuries noted or visible      false               Arrest
# 2         false  No injuries noted or visible      false               Arrest
# 3         false  No injuries noted or visible      false       Call for Cover
# 4          true  No injuries noted or visible      false               Arrest
# ...         ...                           ...        ...                  ...
# 2939      false  No injuries noted or visible      false  Suspicious Activity
# 2940      false  No injuries noted or visible      false         Traffic Stop
# 2941      false  No injuries noted or visible      false        Crowd Control
# 2942      false  No injuries noted or visible      false    Crime in Progress
# 2943      false  No injuries noted or visible      false    Crime in Progress
#
#                                    forcetype       uof_reason cycles_num  \
# 0                 BD - Tripped, BD - Grabbed  Detention/Frisk       NULL
# 1                          Held Suspect Down           Arrest       NULL
# 2                             K-9 Deployment           Arrest       NULL
# 3                                Joint Locks           Arrest       NULL
# 4                  Joint Locks, BD - Grabbed           Arrest       NULL
# ...                                      ...              ...        ...
# 2939                 Taser Display at Person   Weapon Display       NULL
# 2940            BD - Grabbed, Verbal Command           Arrest       NULL
# 2941  Verbal Command, OC Spray, Foot Pursuit           Arrest       NULL
# 2942            Verbal Command, Foot Pursuit   Weapon Display       NULL
# 2943            Verbal Command, Foot Pursuit           Arrest       NULL
#
#        forceeffec street_n     street street_g street_t  \
# 0        Yes, Yes      102   Beltline        S      Rd.
# 1             Yes     1500  Oak Cliff        S    Blvd.
# 2             Yes     6904    Walling     NULL      Ln.
# 3             Yes    11760   Ferguson     NULL      Rd.
# 4        Yes, Yes     1350    Skyline     NULL      Rd.
# ...           ...      ...        ...      ...      ...
# 2939          Yes     1500   Park Row     NULL     Ave.
# 2940     Yes, Yes     3300   Illinois        W     Ave.
# 2941  No, Yes, No     3012  HENDERSON        N     Ave.
# 2942       No, No    11217    Garland     NULL      Rd.
# 2943      No, Yes     1100   Oak Park     NULL      Dr.
#
#                      address      citnum   citrace  citsex cit_injure
# 0         102 S Beltline Rd.       60833     White    Male      false
# 1     1500 S Oak Cliff Blvd.  6020748798  Hispanic  Female       true
# 2           6904 Walling Ln.       61130     Black    Male       true
# 3         11760 Ferguson Rd.       26625     White  Female      false
# 4           1350 Skyline Rd.       59513     Black    Male      false
# ...                      ...         ...       ...     ...        ...
# 2939      1500 Park Row Ave.       59597     Black    Male      false
# 2940   3300 W Illinois  Ave.       58359     Black    Male      false
# 2941   3012 N HENDERSON Ave.       54155     White    Male       true
# 2942       11217 Garland Rd.       58106     Asian    Male      false
# 2943       1100 Oak Park Dr.       59519     Black    Male      false
#
# [2944 rows x 17 columns]
