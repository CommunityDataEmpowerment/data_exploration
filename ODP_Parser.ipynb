# %%
import requests
import json

# %%
r = requests.get('https://www.dallasopendata.com/api/catalog/v1?ids=qv6i-rri7')

# %%
r.json()['results'][0]['resource']
# Out:
# {'name': 'Police Incidents',
#  'id': 'qv6i-rri7',
#  'parent_fxf': None,
# ...
